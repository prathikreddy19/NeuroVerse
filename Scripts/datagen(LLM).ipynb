# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import torch
import torch.nn as nn
from scipy.integrate import solve_ivp
import matplotlib.pyplot as plt

# %%
# Load latent embeddings and cohort statistics
latents = np.load("/content/drive/MyDrive/latents.npy")
cohort_mu = np.load("/content/drive/MyDrive/cohort_mu.npy")
cohort_sigma = np.load("/content/drive/MyDrive/cohort_sigma.npy")

print(f"Latents shape: {latents.shape}")
print(f"Cohort mean shape: {cohort_mu.shape}")
print(f"Cohort covariance shape: {cohort_sigma.shape}")
# Out:
# Latents shape: (1064, 16)
# Cohort mean shape: (16,)
# Cohort covariance shape: (16, 16)

# %%
class NeuroCore:
    def __init__(self, W, tau=1.0, eta=-5.0, Delta=1.0, J=15.0, I_ext=0.0):
        self.W = W
        self.N = W.shape[0]
        self.tau = tau
        self.eta = eta
        self.Delta = Delta
        self.J = J
        self.I_ext = I_ext

    def montbrio_equations(self, t, y):
        N = self.N
        r = y[:N]
        V = y[N:]
        coupling = self.W @ r
        dr_dt = (self.Delta / np.pi + 2 * r * V) / self.tau
        dV_dt = (V**2 + self.eta + self.J * coupling + self.I_ext) / self.tau
        return np.concatenate([dr_dt, dV_dt])

    def simulate(self, r0=None, V0=None, t_max=100.0, dt=0.1):
        N = self.N
        t_eval = np.arange(0, t_max, dt)
        if r0 is None: r0 = 0.1 * np.ones(N)
        if V0 is None: V0 = -5.0 * np.ones(N)
        y0 = np.concatenate([r0, V0])
        sol = solve_ivp(self.montbrio_equations, [0, t_max], y0, t_eval=t_eval, method="RK45")
        return t_eval, sol.y[:N], sol.y[N:]

# %%
class CrossCoder(nn.Module):
    def __init__(self, parcellation_dims, latent_dim=16):
        super(CrossCoder, self).__init__()
        self.parcellations = list(parcellation_dims.keys())
        self.latent_dim = latent_dim

        # Encoder blocks
        self.encoders = nn.ModuleDict()
        for parc, input_dim in parcellation_dims.items():
            self.encoders[parc] = nn.Sequential(
                nn.Linear(input_dim, 1024),
                nn.ReLU(),
                nn.Dropout(0.3),
                nn.Linear(1024, 512),
                nn.ReLU(),
                nn.Dropout(0.3),
                nn.Linear(512, 128),
                nn.ReLU(),
                nn.Linear(128, latent_dim)
            )

        # Decoder blocks
        self.decoders = nn.ModuleDict()
        for parc, input_dim in parcellation_dims.items():
            self.decoders[parc] = nn.Sequential(
                nn.Linear(latent_dim, 128),
                nn.ReLU(),
                nn.Linear(128, 512),
                nn.ReLU(),
                nn.Linear(512, 1024),
                nn.ReLU(),
                nn.Linear(1024, input_dim)
            )

    def encode(self, x, parcellation):
        if parcellation not in self.encoders:
            raise KeyError(f"Unknown parcellation key: {parcellation}")
        return self.encoders[parcellation](x)

    def decode(self, z, parcellation):
        if parcellation not in self.decoders:
            raise KeyError(f"Unknown parcellation key: {parcellation}")
        return self.decoders[parcellation](z) # Added return statement

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Load the saved state dictionary
checkpoint = torch.load("/content/drive/MyDrive/crosscoder_fixed.pth", map_location=device)

# Instantiate the model (replace CrossCoder with your actual model class)
# You will need the correct parcellation_dims and latent_dim
parcellation_dims = checkpoint['parcellation_dims'] # Get from loaded dictionary
latent_dim = checkpoint['latent_dim'] # Get from loaded dictionary
crosscoder = CrossCoder(parcellation_dims, latent_dim).to(device)

# Load the state dictionary into the model
crosscoder.load_state_dict(checkpoint['model_state_dict'])

crosscoder.eval()

# Make sure 'latent' tensor is available
# Example: latent = torch.load("/content/drive/MyDrive/latents.pth")
# Out:
# CrossCoder(
#   (encoders): ModuleDict(
#     (parc_86): Sequential(
#       (0): Linear(in_features=3403, out_features=1024, bias=True)
#       (1): ReLU()
#       (2): Dropout(p=0.3, inplace=False)
#       (3): Linear(in_features=1024, out_features=512, bias=True)
#       (4): ReLU()
#       (5): Dropout(p=0.3, inplace=False)
#       (6): Linear(in_features=512, out_features=128, bias=True)
#       (7): ReLU()
#       (8): Linear(in_features=128, out_features=16, bias=True)
#     )
#     (parc_129): Sequential(
#       (0): Linear(in_features=8256, out_features=1024, bias=True)
#       (1): ReLU()
#       (2): Dropout(p=0.3, inplace=False)
#       (3): Linear(in_features=1024, out_features=512, bias=True)
#       (4): ReLU()
#       (5): Dropout(p=0.3, inplace=False)
#       (6): Linear(in_features=512, out_features=128, bias=True)
#       (7): ReLU()
#       (8): Linear(in_features=128, out_features=16, bias=True)
#     )
#     (parc_234): Sequential(
#       (0): Linear(in_features=27261, out_features=1024, bias=True)
#       (1): ReLU()
#       (2): Dropout(p=0.3, inplace=False)
#       (3): Linear(in_features=1024, out_features=512, bias=True)
#       (4): ReLU()
#       (5): Dropout(p=0.3, inplace=False)
#       (6): Linear(in_features=512, out_features=128, bias=True)
#       (7): ReLU()
#       (8): Linear(in_features=128, out_features=16, bias=True)
#     )
#     (parc_463): Sequential(
#       (0): Linear(in_features=106953, out_features=1024, bias=True)
#       (1): ReLU()
#       (2): Dropout(p=0.3, inplace=False)
#       (3): Linear(in_features=1024, out_features=512, bias=True)
#       (4): ReLU()
#       (5): Dropout(p=0.3, inplace=False)
#       (6): Linear(in_features=512, out_features=128, bias=True)
#       (7): ReLU()
#       (8): Linear(in_features=128, out_features=16, bias=True)
#     )
#   )
#   (decoders): ModuleDict(
#     (parc_86): Sequential(
#       (0): Linear(in_features=16, out_features=128, bias=True)
#       (1): ReLU()
#       (2): Linear(in_features=128, out_features=512, bias=True)
#       (3): ReLU()
#       (4): Linear(in_features=512, out_features=1024, bias=True)
#       (5): ReLU()
#       (6): Linear(in_features=1024, out_features=3403, bias=True)
#     )
#     (parc_129): Sequential(
#       (0): Linear(in_features=16, out_features=128, bias=True)
#       (1): ReLU()
#       (2): Linear(in_features=128, out_features=512, bias=True)
#       (3): ReLU()
#       (4): Linear(in_features=512, out_features=1024, bias=True)
#       (5): ReLU()
#       (6): Linear(in_features=1024, out_features=8256, bias=True)
#     )
#     (parc_234): Sequential(
#       (0): Linear(in_features=16, out_features=128, bias=True)
#       (1): ReLU()
#       (2): Linear(in_features=128, out_features=512, bias=True)
#       (3): ReLU()
#       (4): Linear(in_features=512, out_features=1024, bias=True)
#       (5): ReLU()
#       (6): Linear(in_features=1024, out_features=27261, bias=True)
#     )
#     (parc_463): Sequential(
#       (0): Linear(in_features=16, out_features=128, bias=True)
#       (1): ReLU()
#       (2): Linear(in_features=128, out_features=512, bias=True)
#       (3): ReLU()
#       (4): Linear(in_features=512, out_features=1024, bias=True)
#       (5): ReLU()
#       (6): Linear(in_features=1024, out_features=106953, bias=True)
#     )
#   )
# )

# %%
import numpy as np
import torch
from scipy.integrate import solve_ivp
import pandas as pd

# ---------------------------
# Load CrossCoder and Latents
# ---------------------------

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
crosscoder = crosscoder.to(device)
crosscoder.eval()

print("✅ Loaded latents:", latents.shape)


# ---------------------------
# Helper: Decode latent -> Symmetric matrix
# ---------------------------

def vector_to_symmetric_matrix(vec, n_regions=463):
    mat = np.zeros((n_regions, n_regions))
    iu = np.triu_indices(n_regions, k=1)
    mat[iu] = vec[:len(iu[0])]
    mat = mat + mat.T
    np.fill_diagonal(mat, 0)
    return mat


# ---------------------------
# NeuroCore Simulation Model
# ---------------------------

class NeuroCore:
    def __init__(self, W, tau=1.0, eta=-5.0, Delta=1.0, J=15.0, I_ext=0.0):
        self.W = W
        self.N = W.shape[0]
        self.tau = tau
        self.eta = eta
        self.Delta = Delta
        self.J = J
        self.I_ext = I_ext

    def montbrio_equations(self, t, y):
        N = self.N
        r = y[:N]
        V = y[N:]
        coupling = self.W @ r
        dr_dt = (self.Delta / np.pi + 2 * r * V) / self.tau
        dV_dt = (V**2 + self.eta + self.J * coupling + self.I_ext) / self.tau
        return np.concatenate([dr_dt, dV_dt])

    def simulate(self, r0=None, V0=None, t_max=100.0, dt=0.1):
        N = self.N
        t_eval = np.arange(0, t_max, dt)
        if r0 is None: r0 = 0.1 * np.ones(N)
        if V0 is None: V0 = -5.0 * np.ones(N)
        y0 = np.concatenate([r0, V0])
        sol = solve_ivp(self.montbrio_equations, [0, t_max], y0, t_eval=t_eval, method="RK45")
        return t_eval, sol.y[:N], sol.y[N:]


# ---------------------------
# Brain state interpretation logic
# ---------------------------

def interpret_brain_state(mean_r, mean_V):
    """
    Simplified 3-state interpretation: 'suppressed', 'normal', 'hyperactive'.
    """

    # 1️⃣ Suppressed (low firing, low voltage)
    if mean_r < 0.15 and mean_V < -4.5:
        return "suppressed", "Neural activity is reduced — consider increasing excitatory drive or lowering inhibition."

    # 2️⃣ Normal (balanced/moderate range)
    elif 0.15 <= mean_r < 0.45 and -4.5 <= mean_V < -2.0:
        return "normal", "Stable network dynamics — no major modulation needed."

    # 3️⃣ Hyperactive (high firing or depolarized)
    elif mean_r >= 0.45 or mean_V >= -2.0:
        return "hyperactive", "Overexcitation detected — recommend reducing excitatory coupling or adding inhibitory feedback."

    # Fallback (very rare)
    else:
        return "normal", "Dynamics within near-normal range — maintain current parameters."


# ---------------------------
# Dataset generation loop
# ---------------------------

results = []

for i, latent in enumerate(latents):
    try:
        z = torch.tensor(latent, dtype=torch.float32).unsqueeze(0).to(device)

        # Decode using CrossCoder
        decoded = crosscoder.decode(z, "parc_463")
        decoded = decoded.detach().cpu().numpy().flatten()

        # Convert to symmetric connectivity matrix
        W_463 = vector_to_symmetric_matrix(decoded, 463)

        # Simulate brain dynamics
        neurocore = NeuroCore(W_463)
        t, r, V = neurocore.simulate(t_max=100.0, dt=0.1)

        # Compute mean features
        mean_r = np.mean(r)
        mean_V = np.mean(V)

        # Interpret and advise
        state, advice = interpret_brain_state(mean_r, mean_V)

        results.append({
            "brain_id": i,
            "mean_r": mean_r,
            "mean_V": mean_V,
            "state": state,
            "advice": advice
        })

        print(f"✅ Processed brain {i+1}/{len(latents)} — {state}")

    except Exception as e:
        print(f"❌ Error processing brain {i}: {e}")
        continue


# ---------------------------
# Save dataset as CSV
# ---------------------------

df = pd.DataFrame(results)
df.to_csv("neurocore_advice_dataset.csv", index=False)
print("✅ Dataset saved to neurocore_advice_dataset.csv")
print(df.head())
# Out:
# ✅ Loaded latents: (1064, 16)
# ✅ Processed brain 1/1064 — normal
# ✅ Processed brain 2/1064 — normal
# ✅ Processed brain 3/1064 — normal
# ✅ Processed brain 4/1064 — normal
# ✅ Processed brain 5/1064 — normal
# ✅ Processed brain 6/1064 — normal
# ✅ Processed brain 7/1064 — normal
# ✅ Processed brain 8/1064 — normal
# ✅ Processed brain 9/1064 — normal
# ✅ Processed brain 10/1064 — normal
# ✅ Processed brain 11/1064 — normal
# ✅ Processed brain 12/1064 — normal
# ✅ Processed brain 13/1064 — normal
# ✅ Processed brain 14/1064 — normal
# ✅ Processed brain 15/1064 — normal
# ✅ Processed brain 16/1064 — normal
# ✅ Processed brain 17/1064 — normal
# ✅ Processed brain 18/1064 — normal
# ✅ Processed brain 19/1064 — normal
# ✅ Processed brain 20/1064 — normal
# ✅ Processed brain 21/1064 — normal
# ✅ Processed brain 22/1064 — normal
# ✅ Processed brain 23/1064 — normal
# ✅ Processed brain 24/1064 — normal
# ✅ Processed brain 25/1064 — normal
# ✅ Processed brain 26/1064 — normal
# ✅ Processed brain 27/1064 — normal
# ✅ Processed brain 28/1064 — normal
# ✅ Processed brain 29/1064 — normal
# ✅ Processed brain 30/1064 — normal
# ✅ Processed brain 31/1064 — normal
# ✅ Processed brain 32/1064 — normal
# ✅ Processed brain 33/1064 — normal
# ✅ Processed brain 34/1064 — normal
# ✅ Processed brain 35/1064 — normal
# ✅ Processed brain 36/1064 — normal
# ✅ Processed brain 37/1064 — normal
# ✅ Processed brain 38/1064 — normal
# ✅ Processed brain 39/1064 — normal
# ✅ Processed brain 40/1064 — normal
# ✅ Processed brain 41/1064 — normal
# ✅ Processed brain 42/1064 — normal
# ✅ Processed brain 43/1064 — normal
# ✅ Processed brain 44/1064 — normal
# ✅ Processed brain 45/1064 — normal
# ✅ Processed brain 46/1064 — normal
# ✅ Processed brain 47/1064 — normal
# ✅ Processed brain 48/1064 — normal
# ✅ Processed brain 49/1064 — normal
# ✅ Processed brain 50/1064 — normal
# ✅ Processed brain 51/1064 — normal
# ✅ Processed brain 52/1064 — normal
# ✅ Processed brain 53/1064 — normal
# ✅ Processed brain 54/1064 — normal
# ✅ Processed brain 55/1064 — normal
# ✅ Processed brain 56/1064 — normal
# ✅ Processed brain 57/1064 — normal
# ✅ Processed brain 58/1064 — normal
# ✅ Processed brain 59/1064 — normal
# ✅ Processed brain 60/1064 — normal
# ✅ Processed brain 61/1064 — normal
# ✅ Processed brain 62/1064 — normal
# ✅ Processed brain 63/1064 — normal
# ✅ Processed brain 64/1064 — normal
# ✅ Processed brain 65/1064 — normal
# ✅ Processed brain 66/1064 — normal
# ✅ Processed brain 67/1064 — normal
# ✅ Processed brain 68/1064 — normal
# ✅ Processed brain 69/1064 — normal
# ✅ Processed brain 70/1064 — normal
# ✅ Processed brain 71/1064 — normal
# ✅ Processed brain 72/1064 — normal
# ✅ Processed brain 73/1064 — normal
# ✅ Processed brain 74/1064 — normal
# ✅ Processed brain 75/1064 — normal
# ✅ Processed brain 76/1064 — normal
# ✅ Processed brain 77/1064 — normal
# ✅ Processed brain 78/1064 — normal
# ✅ Processed brain 79/1064 — normal
# ✅ Processed brain 80/1064 — normal
# ✅ Processed brain 81/1064 — normal
# ✅ Processed brain 82/1064 — normal
# ✅ Processed brain 83/1064 — normal
# ✅ Processed brain 84/1064 — normal
# ✅ Processed brain 85/1064 — normal
# ✅ Processed brain 86/1064 — normal
# ✅ Processed brain 87/1064 — normal
# ✅ Processed brain 88/1064 — normal
# ✅ Processed brain 89/1064 — normal
# ✅ Processed brain 90/1064 — normal
# ✅ Processed brain 91/1064 — normal
# ✅ Processed brain 92/1064 — normal
# ✅ Processed brain 93/1064 — normal
# ✅ Processed brain 94/1064 — normal
# ✅ Processed brain 95/1064 — normal
# ✅ Processed brain 96/1064 — normal
# ✅ Processed brain 97/1064 — normal
# ✅ Processed brain 98/1064 — normal
# ✅ Processed brain 99/1064 — normal
# ✅ Processed brain 100/1064 — normal
# ✅ Processed brain 101/1064 — normal
# ✅ Processed brain 102/1064 — normal
# ✅ Processed brain 103/1064 — normal
# ✅ Processed brain 104/1064 — normal
# ✅ Processed brain 105/1064 — normal
# ✅ Processed brain 106/1064 — normal
# ✅ Processed brain 107/1064 — normal
# ✅ Processed brain 108/1064 — normal
# ✅ Processed brain 109/1064 — normal
# ✅ Processed brain 110/1064 — normal
# ✅ Processed brain 111/1064 — normal
# ✅ Processed brain 112/1064 — normal
# ✅ Processed brain 113/1064 — normal
# ✅ Processed brain 114/1064 — normal
# ✅ Processed brain 115/1064 — normal
# ✅ Processed brain 116/1064 — normal
# ✅ Processed brain 117/1064 — normal
# ✅ Processed brain 118/1064 — normal
# ✅ Processed brain 119/1064 — normal
# ✅ Processed brain 120/1064 — normal
# ✅ Processed brain 121/1064 — normal
# ✅ Processed brain 122/1064 — normal
# ✅ Processed brain 123/1064 — normal
# ✅ Processed brain 124/1064 — normal
# ✅ Processed brain 125/1064 — normal
# ✅ Processed brain 126/1064 — normal
# ✅ Processed brain 127/1064 — normal
# ✅ Processed brain 128/1064 — normal
# ✅ Processed brain 129/1064 — normal
# ✅ Processed brain 130/1064 — normal
# ✅ Processed brain 131/1064 — normal
# ✅ Processed brain 132/1064 — normal
# ✅ Processed brain 133/1064 — normal
# ✅ Processed brain 134/1064 — normal
# ✅ Processed brain 135/1064 — normal
# ✅ Processed brain 136/1064 — normal
# ✅ Processed brain 137/1064 — normal
# ✅ Processed brain 138/1064 — normal
# ✅ Processed brain 139/1064 — normal
# ✅ Processed brain 140/1064 — normal
# ✅ Processed brain 141/1064 — normal
# ✅ Processed brain 142/1064 — normal
# ✅ Processed brain 143/1064 — normal
# ✅ Processed brain 144/1064 — normal
# ✅ Processed brain 145/1064 — normal
# ✅ Processed brain 146/1064 — normal
# ✅ Processed brain 147/1064 — normal
# ✅ Processed brain 148/1064 — normal
# ✅ Processed brain 149/1064 — normal
# ✅ Processed brain 150/1064 — normal
# ✅ Processed brain 151/1064 — normal
# ✅ Processed brain 152/1064 — normal
# ✅ Processed brain 153/1064 — normal
# ✅ Processed brain 154/1064 — normal
# ✅ Processed brain 155/1064 — normal
# ✅ Processed brain 156/1064 — normal
# ✅ Processed brain 157/1064 — normal
# ✅ Processed brain 158/1064 — normal
# ✅ Processed brain 159/1064 — normal
# ✅ Processed brain 160/1064 — normal
# ✅ Processed brain 161/1064 — normal
# ✅ Processed brain 162/1064 — normal
# ✅ Processed brain 163/1064 — normal
# ✅ Processed brain 164/1064 — normal
# ✅ Processed brain 165/1064 — normal
# ✅ Processed brain 166/1064 — normal
# ✅ Processed brain 167/1064 — normal
# ✅ Processed brain 168/1064 — normal
# ✅ Processed brain 169/1064 — normal
# ✅ Processed brain 170/1064 — normal
# ✅ Processed brain 171/1064 — normal
# ✅ Processed brain 172/1064 — normal
# ✅ Processed brain 173/1064 — normal
# ✅ Processed brain 174/1064 — normal
# ✅ Processed brain 175/1064 — normal
# ✅ Processed brain 176/1064 — normal
# ✅ Processed brain 177/1064 — normal
# ✅ Processed brain 178/1064 — normal
# ✅ Processed brain 179/1064 — normal
# ✅ Processed brain 180/1064 — normal
# ✅ Processed brain 181/1064 — normal
# ✅ Processed brain 182/1064 — normal
# ✅ Processed brain 183/1064 — normal
# ✅ Processed brain 184/1064 — normal
# ✅ Processed brain 185/1064 — normal
# ✅ Processed brain 186/1064 — normal
# ✅ Processed brain 187/1064 — normal
# ✅ Processed brain 188/1064 — normal
# ✅ Processed brain 189/1064 — normal
# ✅ Processed brain 190/1064 — normal
# ✅ Processed brain 191/1064 — normal
# ✅ Processed brain 192/1064 — normal
# ✅ Processed brain 193/1064 — normal
# ✅ Processed brain 194/1064 — normal
# ✅ Processed brain 195/1064 — normal
# ✅ Processed brain 196/1064 — normal
# ✅ Processed brain 197/1064 — normal
# ✅ Processed brain 198/1064 — normal
# ✅ Processed brain 199/1064 — normal
# ✅ Processed brain 200/1064 — normal
# ✅ Processed brain 201/1064 — normal
# ✅ Processed brain 202/1064 — normal
# ✅ Processed brain 203/1064 — normal
# ✅ Processed brain 204/1064 — normal
# ✅ Processed brain 205/1064 — normal
# ✅ Processed brain 206/1064 — normal
# ✅ Processed brain 207/1064 — normal
# ✅ Processed brain 208/1064 — normal
# ✅ Processed brain 209/1064 — normal
# ✅ Processed brain 210/1064 — normal
# ✅ Processed brain 211/1064 — normal
# ✅ Processed brain 212/1064 — normal
# ✅ Processed brain 213/1064 — normal
# ✅ Processed brain 214/1064 — normal
# ✅ Processed brain 215/1064 — normal
# ✅ Processed brain 216/1064 — normal
# ✅ Processed brain 217/1064 — normal
# ✅ Processed brain 218/1064 — normal
# ✅ Processed brain 219/1064 — normal
# ✅ Processed brain 220/1064 — normal
# ✅ Processed brain 221/1064 — normal
# ✅ Processed brain 222/1064 — normal
# ✅ Processed brain 223/1064 — normal
# ✅ Processed brain 224/1064 — normal
# ✅ Processed brain 225/1064 — normal
# ✅ Processed brain 226/1064 — normal
# ✅ Processed brain 227/1064 — normal
# ✅ Processed brain 228/1064 — normal
# ✅ Processed brain 229/1064 — normal
# ✅ Processed brain 230/1064 — normal
# ✅ Processed brain 231/1064 — normal
# ✅ Processed brain 232/1064 — normal
# ✅ Processed brain 233/1064 — normal
# ✅ Processed brain 234/1064 — normal
# ✅ Processed brain 235/1064 — normal
# ✅ Processed brain 236/1064 — normal
# ✅ Processed brain 237/1064 — normal
# ✅ Processed brain 238/1064 — normal
# ✅ Processed brain 239/1064 — normal
# ✅ Processed brain 240/1064 — normal
# ✅ Processed brain 241/1064 — normal
# ✅ Processed brain 242/1064 — normal
# ✅ Processed brain 243/1064 — normal
# ✅ Processed brain 244/1064 — normal
# ✅ Processed brain 245/1064 — normal
# ✅ Processed brain 246/1064 — normal
# ✅ Processed brain 247/1064 — normal
# ✅ Processed brain 248/1064 — normal
# ✅ Processed brain 249/1064 — normal
# ✅ Processed brain 250/1064 — normal
# ✅ Processed brain 251/1064 — normal
# ✅ Processed brain 252/1064 — normal
# ✅ Processed brain 253/1064 — normal
# ✅ Processed brain 254/1064 — normal
# ✅ Processed brain 255/1064 — normal
# ✅ Processed brain 256/1064 — normal
# ✅ Processed brain 257/1064 — normal
# ✅ Processed brain 258/1064 — normal
# ✅ Processed brain 259/1064 — normal
# ✅ Processed brain 260/1064 — normal
# ✅ Processed brain 261/1064 — normal
# ✅ Processed brain 262/1064 — normal
# ✅ Processed brain 263/1064 — normal
# ✅ Processed brain 264/1064 — normal
# ✅ Processed brain 265/1064 — normal
# ✅ Processed brain 266/1064 — normal
# ✅ Processed brain 267/1064 — normal
# ✅ Processed brain 268/1064 — normal
# ✅ Processed brain 269/1064 — normal
# ✅ Processed brain 270/1064 — normal
# ✅ Processed brain 271/1064 — normal
# ✅ Processed brain 272/1064 — normal
# ✅ Processed brain 273/1064 — normal
# ✅ Processed brain 274/1064 — normal
# ✅ Processed brain 275/1064 — normal
# ✅ Processed brain 276/1064 — normal
# ✅ Processed brain 277/1064 — normal
# ✅ Processed brain 278/1064 — normal
# ✅ Processed brain 279/1064 — normal
# ✅ Processed brain 280/1064 — normal
# ✅ Processed brain 281/1064 — normal
# ✅ Processed brain 282/1064 — normal
# ✅ Processed brain 283/1064 — normal
# ✅ Processed brain 284/1064 — normal
# ✅ Processed brain 285/1064 — normal
# ✅ Processed brain 286/1064 — normal
# ✅ Processed brain 287/1064 — normal
# ✅ Processed brain 288/1064 — normal
# ✅ Processed brain 289/1064 — normal
# ✅ Processed brain 290/1064 — normal
# ✅ Processed brain 291/1064 — normal
# ✅ Processed brain 292/1064 — normal
# ✅ Processed brain 293/1064 — normal
# ✅ Processed brain 294/1064 — normal
# ✅ Processed brain 295/1064 — normal
# ✅ Processed brain 296/1064 — normal
# ✅ Processed brain 297/1064 — normal
# ✅ Processed brain 298/1064 — normal
# ✅ Processed brain 299/1064 — normal
# ✅ Processed brain 300/1064 — normal
# ✅ Processed brain 301/1064 — normal
# ✅ Processed brain 302/1064 — normal
# ✅ Processed brain 303/1064 — normal
# ✅ Processed brain 304/1064 — normal
# ✅ Processed brain 305/1064 — normal
# ✅ Processed brain 306/1064 — normal
# ✅ Processed brain 307/1064 — normal
# ✅ Processed brain 308/1064 — normal
# ✅ Processed brain 309/1064 — normal
# ✅ Processed brain 310/1064 — normal
# ✅ Processed brain 311/1064 — normal
# ✅ Processed brain 312/1064 — normal
# ✅ Processed brain 313/1064 — normal
# ✅ Processed brain 314/1064 — normal
# ✅ Processed brain 315/1064 — normal
# ✅ Processed brain 316/1064 — normal
# ✅ Processed brain 317/1064 — normal
# ✅ Processed brain 318/1064 — normal
# ✅ Processed brain 319/1064 — normal
# ✅ Processed brain 320/1064 — normal
# ✅ Processed brain 321/1064 — normal
# ✅ Processed brain 322/1064 — normal
# ✅ Processed brain 323/1064 — normal
# ✅ Processed brain 324/1064 — normal
# ✅ Processed brain 325/1064 — normal
# ✅ Processed brain 326/1064 — normal
# ✅ Processed brain 327/1064 — normal
# ✅ Processed brain 328/1064 — normal
# ✅ Processed brain 329/1064 — normal
# ✅ Processed brain 330/1064 — normal
# ✅ Processed brain 331/1064 — normal
# ✅ Processed brain 332/1064 — normal
# ✅ Processed brain 333/1064 — normal
# ✅ Processed brain 334/1064 — normal
# ✅ Processed brain 335/1064 — normal
# ✅ Processed brain 336/1064 — normal
# ✅ Processed brain 337/1064 — normal
# ✅ Processed brain 338/1064 — normal
# ✅ Processed brain 339/1064 — normal
# ✅ Processed brain 340/1064 — normal
# ✅ Processed brain 341/1064 — normal
# ✅ Processed brain 342/1064 — normal
# ✅ Processed brain 343/1064 — normal
# ✅ Processed brain 344/1064 — normal
# ✅ Processed brain 345/1064 — normal
# ✅ Processed brain 346/1064 — normal
# ✅ Processed brain 347/1064 — normal
# ✅ Processed brain 348/1064 — normal
# ✅ Processed brain 349/1064 — normal
# ✅ Processed brain 350/1064 — normal
# ✅ Processed brain 351/1064 — normal
# ✅ Processed brain 352/1064 — normal
# ✅ Processed brain 353/1064 — normal
# ✅ Processed brain 354/1064 — normal
# ✅ Processed brain 355/1064 — normal
# ✅ Processed brain 356/1064 — normal
# ✅ Processed brain 357/1064 — normal
# ✅ Processed brain 358/1064 — normal
# ✅ Processed brain 359/1064 — normal
# ✅ Processed brain 360/1064 — normal
# ✅ Processed brain 361/1064 — normal
# ✅ Processed brain 362/1064 — normal
# ✅ Processed brain 363/1064 — normal
# ✅ Processed brain 364/1064 — normal
# ✅ Processed brain 365/1064 — normal
# ✅ Processed brain 366/1064 — normal
# ✅ Processed brain 367/1064 — normal
# ✅ Processed brain 368/1064 — normal
# ✅ Processed brain 369/1064 — normal
# ✅ Processed brain 370/1064 — normal
# ✅ Processed brain 371/1064 — normal
# ✅ Processed brain 372/1064 — normal
# ✅ Processed brain 373/1064 — normal
# ✅ Processed brain 374/1064 — normal
# ✅ Processed brain 375/1064 — normal
# ✅ Processed brain 376/1064 — normal
# ✅ Processed brain 377/1064 — normal
# ✅ Processed brain 378/1064 — normal
# ✅ Processed brain 379/1064 — normal
# ✅ Processed brain 380/1064 — normal
# ✅ Processed brain 381/1064 — normal
# ✅ Processed brain 382/1064 — normal
# ✅ Processed brain 383/1064 — normal
# ✅ Processed brain 384/1064 — normal
# ✅ Processed brain 385/1064 — normal
# ✅ Processed brain 386/1064 — normal
# ✅ Processed brain 387/1064 — normal
# ✅ Processed brain 388/1064 — normal
# ✅ Processed brain 389/1064 — normal
# ✅ Processed brain 390/1064 — normal
# ✅ Processed brain 391/1064 — normal
# ✅ Processed brain 392/1064 — normal
# ✅ Processed brain 393/1064 — normal
# ✅ Processed brain 394/1064 — normal
# ✅ Processed brain 395/1064 — normal
# ✅ Processed brain 396/1064 — normal
# ✅ Processed brain 397/1064 — normal
# ✅ Processed brain 398/1064 — normal
# ✅ Processed brain 399/1064 — normal
# ✅ Processed brain 400/1064 — normal
# ✅ Processed brain 401/1064 — normal
# ✅ Processed brain 402/1064 — normal
# ✅ Processed brain 403/1064 — normal
# ✅ Processed brain 404/1064 — normal
# ✅ Processed brain 405/1064 — normal
# ✅ Processed brain 406/1064 — normal
# ✅ Processed brain 407/1064 — normal
# ✅ Processed brain 408/1064 — normal
# ✅ Processed brain 409/1064 — normal
# ✅ Processed brain 410/1064 — normal
# ✅ Processed brain 411/1064 — normal
# ✅ Processed brain 412/1064 — normal
# ✅ Processed brain 413/1064 — normal
# ✅ Processed brain 414/1064 — normal
# ✅ Processed brain 415/1064 — normal
# ✅ Processed brain 416/1064 — normal
# ✅ Processed brain 417/1064 — normal
# ✅ Processed brain 418/1064 — normal
# ✅ Processed brain 419/1064 — normal
# ✅ Processed brain 420/1064 — normal
# ✅ Processed brain 421/1064 — normal
# ✅ Processed brain 422/1064 — normal
# ✅ Processed brain 423/1064 — normal
# ✅ Processed brain 424/1064 — normal
# ✅ Processed brain 425/1064 — normal
# ✅ Processed brain 426/1064 — normal
# ✅ Processed brain 427/1064 — normal
# ✅ Processed brain 428/1064 — normal
# ✅ Processed brain 429/1064 — normal
# ✅ Processed brain 430/1064 — normal
# ✅ Processed brain 431/1064 — normal
# ✅ Processed brain 432/1064 — normal
# ✅ Processed brain 433/1064 — normal
# ✅ Processed brain 434/1064 — normal
# ✅ Processed brain 435/1064 — normal
# ✅ Processed brain 436/1064 — normal
# ✅ Processed brain 437/1064 — normal
# ✅ Processed brain 438/1064 — normal
# ✅ Processed brain 439/1064 — normal
# ✅ Processed brain 440/1064 — normal
# ✅ Processed brain 441/1064 — normal
# ✅ Processed brain 442/1064 — normal
# ✅ Processed brain 443/1064 — normal
# ✅ Processed brain 444/1064 — normal
# ✅ Processed brain 445/1064 — normal
# ✅ Processed brain 446/1064 — normal
# ✅ Processed brain 447/1064 — normal
# ✅ Processed brain 448/1064 — normal
# ✅ Processed brain 449/1064 — normal
# ✅ Processed brain 450/1064 — normal
# ✅ Processed brain 451/1064 — normal
# ✅ Processed brain 452/1064 — normal
# ✅ Processed brain 453/1064 — normal
# ✅ Processed brain 454/1064 — normal
# ✅ Processed brain 455/1064 — normal
# ✅ Processed brain 456/1064 — normal
# ✅ Processed brain 457/1064 — normal
# ✅ Processed brain 458/1064 — normal
# ✅ Processed brain 459/1064 — normal
# ✅ Processed brain 460/1064 — normal
# ✅ Processed brain 461/1064 — normal
# ✅ Processed brain 462/1064 — normal
# ✅ Processed brain 463/1064 — normal
# ✅ Processed brain 464/1064 — normal
# ✅ Processed brain 465/1064 — normal
# ✅ Processed brain 466/1064 — normal
# ✅ Processed brain 467/1064 — normal
# ✅ Processed brain 468/1064 — normal
# ✅ Processed brain 469/1064 — normal
# ✅ Processed brain 470/1064 — normal
# ✅ Processed brain 471/1064 — normal
# ✅ Processed brain 472/1064 — normal
# ✅ Processed brain 473/1064 — normal
# ✅ Processed brain 474/1064 — normal
# ✅ Processed brain 475/1064 — normal
# ✅ Processed brain 476/1064 — normal
# ✅ Processed brain 477/1064 — normal
# ✅ Processed brain 478/1064 — normal
# ✅ Processed brain 479/1064 — normal
# ✅ Processed brain 480/1064 — normal
# ✅ Processed brain 481/1064 — normal
# ✅ Processed brain 482/1064 — normal
# ✅ Processed brain 483/1064 — normal
# ✅ Processed brain 484/1064 — normal
# ✅ Processed brain 485/1064 — normal
# ✅ Processed brain 486/1064 — normal
# ✅ Processed brain 487/1064 — normal
# ✅ Processed brain 488/1064 — normal
# ✅ Processed brain 489/1064 — normal
# ✅ Processed brain 490/1064 — normal
# ✅ Processed brain 491/1064 — normal
# ✅ Processed brain 492/1064 — normal
# ✅ Processed brain 493/1064 — normal
# ✅ Processed brain 494/1064 — normal
# ✅ Processed brain 495/1064 — normal
# ✅ Processed brain 496/1064 — normal
# ✅ Processed brain 497/1064 — normal
# ✅ Processed brain 498/1064 — normal
# ✅ Processed brain 499/1064 — normal
# ✅ Processed brain 500/1064 — normal
# ✅ Processed brain 501/1064 — normal
# ✅ Processed brain 502/1064 — normal
# ✅ Processed brain 503/1064 — normal
# ✅ Processed brain 504/1064 — normal
# ✅ Processed brain 505/1064 — normal
# ✅ Processed brain 506/1064 — normal
# ✅ Processed brain 507/1064 — normal
# ✅ Processed brain 508/1064 — normal
# ✅ Processed brain 509/1064 — normal
# ✅ Processed brain 510/1064 — normal
# ✅ Processed brain 511/1064 — normal
# ✅ Processed brain 512/1064 — normal
# ✅ Processed brain 513/1064 — normal
# ✅ Processed brain 514/1064 — normal
# ✅ Processed brain 515/1064 — normal
# ✅ Processed brain 516/1064 — normal
# ✅ Processed brain 517/1064 — normal
# ✅ Processed brain 518/1064 — normal
# ✅ Processed brain 519/1064 — normal
# ✅ Processed brain 520/1064 — normal
# ✅ Processed brain 521/1064 — normal
# ✅ Processed brain 522/1064 — normal
# ✅ Processed brain 523/1064 — normal
# ✅ Processed brain 524/1064 — normal
# ✅ Processed brain 525/1064 — normal
# ✅ Processed brain 526/1064 — normal
# ✅ Processed brain 527/1064 — normal
# ✅ Processed brain 528/1064 — normal
# ✅ Processed brain 529/1064 — normal
# ✅ Processed brain 530/1064 — normal
# ✅ Processed brain 531/1064 — normal
# ✅ Processed brain 532/1064 — normal
# ✅ Processed brain 533/1064 — normal
# ✅ Processed brain 534/1064 — normal
# ✅ Processed brain 535/1064 — normal
# ✅ Processed brain 536/1064 — normal
# ✅ Processed brain 537/1064 — normal
# ✅ Processed brain 538/1064 — normal
# ✅ Processed brain 539/1064 — normal
# ✅ Processed brain 540/1064 — normal
# ✅ Processed brain 541/1064 — normal
# ✅ Processed brain 542/1064 — normal
# ✅ Processed brain 543/1064 — normal
# ✅ Processed brain 544/1064 — normal
# ✅ Processed brain 545/1064 — normal
# ✅ Processed brain 546/1064 — normal
# ✅ Processed brain 547/1064 — normal
# ✅ Processed brain 548/1064 — normal
# ✅ Processed brain 549/1064 — normal
# ✅ Processed brain 550/1064 — normal
# ✅ Processed brain 551/1064 — normal
# ✅ Processed brain 552/1064 — normal
# ✅ Processed brain 553/1064 — normal
# ✅ Processed brain 554/1064 — normal
# ✅ Processed brain 555/1064 — normal
# ✅ Processed brain 556/1064 — normal
# ✅ Processed brain 557/1064 — normal
# ✅ Processed brain 558/1064 — normal
# ✅ Processed brain 559/1064 — normal
# ✅ Processed brain 560/1064 — normal
# ✅ Processed brain 561/1064 — normal
# ✅ Processed brain 562/1064 — normal
# ✅ Processed brain 563/1064 — normal
# ✅ Processed brain 564/1064 — normal
# ✅ Processed brain 565/1064 — normal
# ✅ Processed brain 566/1064 — normal
# ✅ Processed brain 567/1064 — normal
# ✅ Processed brain 568/1064 — normal
# ✅ Processed brain 569/1064 — normal
# ✅ Processed brain 570/1064 — normal
# ✅ Processed brain 571/1064 — normal
# ✅ Processed brain 572/1064 — normal
# ✅ Processed brain 573/1064 — normal
# ✅ Processed brain 574/1064 — normal
# ✅ Processed brain 575/1064 — normal
# ✅ Processed brain 576/1064 — normal
# ✅ Processed brain 577/1064 — normal
# ✅ Processed brain 578/1064 — normal
# ✅ Processed brain 579/1064 — normal
# ✅ Processed brain 580/1064 — normal
# ✅ Processed brain 581/1064 — normal
# ✅ Processed brain 582/1064 — normal
# ✅ Processed brain 583/1064 — normal
# ✅ Processed brain 584/1064 — normal
# ✅ Processed brain 585/1064 — normal
# ✅ Processed brain 586/1064 — normal
# ✅ Processed brain 587/1064 — normal
# ✅ Processed brain 588/1064 — normal
# ✅ Processed brain 589/1064 — normal
# ✅ Processed brain 590/1064 — normal
# ✅ Processed brain 591/1064 — normal
# ✅ Processed brain 592/1064 — normal
# ✅ Processed brain 593/1064 — normal
# ✅ Processed brain 594/1064 — normal
# ✅ Processed brain 595/1064 — normal
# ✅ Processed brain 596/1064 — normal
# ✅ Processed brain 597/1064 — normal
# ✅ Processed brain 598/1064 — normal
# ✅ Processed brain 599/1064 — normal
# ✅ Processed brain 600/1064 — normal
# ✅ Processed brain 601/1064 — normal
# ✅ Processed brain 602/1064 — normal
# ✅ Processed brain 603/1064 — normal
# ✅ Processed brain 604/1064 — normal
# ✅ Processed brain 605/1064 — normal
# ✅ Processed brain 606/1064 — normal
# ✅ Processed brain 607/1064 — normal
# ✅ Processed brain 608/1064 — normal
# ✅ Processed brain 609/1064 — normal
# ✅ Processed brain 610/1064 — normal
# ✅ Processed brain 611/1064 — normal
# ✅ Processed brain 612/1064 — normal
# ✅ Processed brain 613/1064 — normal
# ✅ Processed brain 614/1064 — normal
# ✅ Processed brain 615/1064 — normal
# ✅ Processed brain 616/1064 — normal
# ✅ Processed brain 617/1064 — normal
# ✅ Processed brain 618/1064 — normal
# ✅ Processed brain 619/1064 — normal
# ✅ Processed brain 620/1064 — normal
# ✅ Processed brain 621/1064 — normal
# ✅ Processed brain 622/1064 — normal
# ✅ Processed brain 623/1064 — normal
# ✅ Processed brain 624/1064 — normal
# ✅ Processed brain 625/1064 — normal
# ✅ Processed brain 626/1064 — normal
# ✅ Processed brain 627/1064 — normal
# ✅ Processed brain 628/1064 — normal
# ✅ Processed brain 629/1064 — normal
# ✅ Processed brain 630/1064 — normal
# ✅ Processed brain 631/1064 — normal
# ✅ Processed brain 632/1064 — normal
# ✅ Processed brain 633/1064 — normal
# ✅ Processed brain 634/1064 — normal
# ✅ Processed brain 635/1064 — normal
# ✅ Processed brain 636/1064 — normal
# ✅ Processed brain 637/1064 — normal
# ✅ Processed brain 638/1064 — normal
# ✅ Processed brain 639/1064 — normal
# ✅ Processed brain 640/1064 — normal
# ✅ Processed brain 641/1064 — normal
# ✅ Processed brain 642/1064 — normal
# ✅ Processed brain 643/1064 — normal
# ✅ Processed brain 644/1064 — normal
# ✅ Processed brain 645/1064 — normal
# ✅ Processed brain 646/1064 — normal
# ✅ Processed brain 647/1064 — normal
# ✅ Processed brain 648/1064 — normal
# ✅ Processed brain 649/1064 — normal
# ✅ Processed brain 650/1064 — normal
# ✅ Processed brain 651/1064 — normal
# ✅ Processed brain 652/1064 — normal
# ✅ Processed brain 653/1064 — normal
# ✅ Processed brain 654/1064 — normal
# ✅ Processed brain 655/1064 — normal
# ✅ Processed brain 656/1064 — normal
# ✅ Processed brain 657/1064 — normal
# ✅ Processed brain 658/1064 — normal
# ✅ Processed brain 659/1064 — normal
# ✅ Processed brain 660/1064 — normal
# ✅ Processed brain 661/1064 — normal
# ✅ Processed brain 662/1064 — normal
# ✅ Processed brain 663/1064 — normal
# ✅ Processed brain 664/1064 — normal
# ✅ Processed brain 665/1064 — normal
# ✅ Processed brain 666/1064 — normal
# ✅ Processed brain 667/1064 — normal
# ✅ Processed brain 668/1064 — normal
# ✅ Processed brain 669/1064 — normal
# ✅ Processed brain 670/1064 — normal
# ✅ Processed brain 671/1064 — normal
# ✅ Processed brain 672/1064 — normal
# ✅ Processed brain 673/1064 — normal
# ✅ Processed brain 674/1064 — normal
# ✅ Processed brain 675/1064 — normal
# ✅ Processed brain 676/1064 — normal
# ✅ Processed brain 677/1064 — normal
# ✅ Processed brain 678/1064 — normal
# ✅ Processed brain 679/1064 — normal
# ✅ Processed brain 680/1064 — normal
# ✅ Processed brain 681/1064 — normal
# ✅ Processed brain 682/1064 — normal
# ✅ Processed brain 683/1064 — normal
# ✅ Processed brain 684/1064 — normal
# ✅ Processed brain 685/1064 — normal
# ✅ Processed brain 686/1064 — normal
# ✅ Processed brain 687/1064 — normal
# ✅ Processed brain 688/1064 — normal
# ✅ Processed brain 689/1064 — normal
# ✅ Processed brain 690/1064 — normal
# ✅ Processed brain 691/1064 — normal
# ✅ Processed brain 692/1064 — normal
# ✅ Processed brain 693/1064 — normal
# ✅ Processed brain 694/1064 — normal
# ✅ Processed brain 695/1064 — normal
# ✅ Processed brain 696/1064 — normal
# ✅ Processed brain 697/1064 — normal
# ✅ Processed brain 698/1064 — normal
# ✅ Processed brain 699/1064 — normal
# ✅ Processed brain 700/1064 — normal
# ✅ Processed brain 701/1064 — normal
# ✅ Processed brain 702/1064 — normal
# ✅ Processed brain 703/1064 — normal
# ✅ Processed brain 704/1064 — normal
# ✅ Processed brain 705/1064 — normal
# ✅ Processed brain 706/1064 — normal
# ✅ Processed brain 707/1064 — normal
# ✅ Processed brain 708/1064 — normal
# ✅ Processed brain 709/1064 — normal
# ✅ Processed brain 710/1064 — normal
# ✅ Processed brain 711/1064 — normal
# ✅ Processed brain 712/1064 — normal
# ✅ Processed brain 713/1064 — normal
# ✅ Processed brain 714/1064 — normal
# ✅ Processed brain 715/1064 — normal
# ✅ Processed brain 716/1064 — normal
# ✅ Processed brain 717/1064 — normal
# ✅ Processed brain 718/1064 — normal
# ✅ Processed brain 719/1064 — normal
# ✅ Processed brain 720/1064 — normal
# ✅ Processed brain 721/1064 — normal
# ✅ Processed brain 722/1064 — normal
# ✅ Processed brain 723/1064 — normal
# ✅ Processed brain 724/1064 — normal
# ✅ Processed brain 725/1064 — normal
# ✅ Processed brain 726/1064 — normal
# ✅ Processed brain 727/1064 — normal
# ✅ Processed brain 728/1064 — normal
# ✅ Processed brain 729/1064 — normal
# ✅ Processed brain 730/1064 — normal
# ✅ Processed brain 731/1064 — normal
# ✅ Processed brain 732/1064 — normal
# ✅ Processed brain 733/1064 — normal
# ✅ Processed brain 734/1064 — normal
# ✅ Processed brain 735/1064 — normal
# ✅ Processed brain 736/1064 — normal
# ✅ Processed brain 737/1064 — normal
# ✅ Processed brain 738/1064 — normal
# ✅ Processed brain 739/1064 — normal
# ✅ Processed brain 740/1064 — normal
# ✅ Processed brain 741/1064 — normal
# ✅ Processed brain 742/1064 — normal
# ✅ Processed brain 743/1064 — normal
# ✅ Processed brain 744/1064 — normal
# ✅ Processed brain 745/1064 — normal
# ✅ Processed brain 746/1064 — normal
# ✅ Processed brain 747/1064 — normal
# ✅ Processed brain 748/1064 — normal
# ✅ Processed brain 749/1064 — normal
# ✅ Processed brain 750/1064 — normal
# ✅ Processed brain 751/1064 — normal
# ✅ Processed brain 752/1064 — normal
# ✅ Processed brain 753/1064 — normal
# ✅ Processed brain 754/1064 — normal
# ✅ Processed brain 755/1064 — normal
# ✅ Processed brain 756/1064 — normal
# ✅ Processed brain 757/1064 — normal
# ✅ Processed brain 758/1064 — normal
# ✅ Processed brain 759/1064 — normal
# ✅ Processed brain 760/1064 — normal
# ✅ Processed brain 761/1064 — normal
# ✅ Processed brain 762/1064 — normal
# ✅ Processed brain 763/1064 — normal
# ✅ Processed brain 764/1064 — normal
# ✅ Processed brain 765/1064 — normal
# ✅ Processed brain 766/1064 — normal
# ✅ Processed brain 767/1064 — normal
# ✅ Processed brain 768/1064 — normal
# ✅ Processed brain 769/1064 — normal
# ✅ Processed brain 770/1064 — normal
# ✅ Processed brain 771/1064 — normal
# ✅ Processed brain 772/1064 — normal
# ✅ Processed brain 773/1064 — normal
# ✅ Processed brain 774/1064 — normal
# ✅ Processed brain 775/1064 — normal
# ✅ Processed brain 776/1064 — normal
# ✅ Processed brain 777/1064 — normal
# ✅ Processed brain 778/1064 — normal
# ✅ Processed brain 779/1064 — normal
# ✅ Processed brain 780/1064 — normal
# ✅ Processed brain 781/1064 — normal
# ✅ Processed brain 782/1064 — normal
# ✅ Processed brain 783/1064 — normal
# ✅ Processed brain 784/1064 — normal
# ✅ Processed brain 785/1064 — normal
# ✅ Processed brain 786/1064 — normal
# ✅ Processed brain 787/1064 — normal
# ✅ Processed brain 788/1064 — normal
# ✅ Processed brain 789/1064 — normal
# ✅ Processed brain 790/1064 — normal
# ✅ Processed brain 791/1064 — normal
# ✅ Processed brain 792/1064 — normal
# ✅ Processed brain 793/1064 — normal
# ✅ Processed brain 794/1064 — normal
# ✅ Processed brain 795/1064 — normal
# ✅ Processed brain 796/1064 — normal
# ✅ Processed brain 797/1064 — normal
# ✅ Processed brain 798/1064 — normal
# ✅ Processed brain 799/1064 — normal
# ✅ Processed brain 800/1064 — normal
# ✅ Processed brain 801/1064 — normal
# ✅ Processed brain 802/1064 — normal
# ✅ Processed brain 803/1064 — normal
# ✅ Processed brain 804/1064 — normal
# ✅ Processed brain 805/1064 — normal
# ✅ Processed brain 806/1064 — normal
# ✅ Processed brain 807/1064 — normal
# ✅ Processed brain 808/1064 — normal
# ✅ Processed brain 809/1064 — normal
# ✅ Processed brain 810/1064 — normal
# ✅ Processed brain 811/1064 — normal
# ✅ Processed brain 812/1064 — normal
# ✅ Processed brain 813/1064 — normal
# ✅ Processed brain 814/1064 — normal
# ✅ Processed brain 815/1064 — normal
# ✅ Processed brain 816/1064 — normal
# ✅ Processed brain 817/1064 — normal
# ✅ Processed brain 818/1064 — normal
# ✅ Processed brain 819/1064 — normal
# ✅ Processed brain 820/1064 — normal
# ✅ Processed brain 821/1064 — normal
# ✅ Processed brain 822/1064 — normal
# ✅ Processed brain 823/1064 — normal
# ✅ Processed brain 824/1064 — normal
# ✅ Processed brain 825/1064 — normal
# ✅ Processed brain 826/1064 — normal
# ✅ Processed brain 827/1064 — normal
# ✅ Processed brain 828/1064 — normal
# ✅ Processed brain 829/1064 — normal
# ✅ Processed brain 830/1064 — normal
# ✅ Processed brain 831/1064 — normal
# ✅ Processed brain 832/1064 — normal
# ✅ Processed brain 833/1064 — normal
# ✅ Processed brain 834/1064 — normal
# ✅ Processed brain 835/1064 — normal
# ✅ Processed brain 836/1064 — normal
# ✅ Processed brain 837/1064 — normal
# ✅ Processed brain 838/1064 — normal
# ✅ Processed brain 839/1064 — normal
# ✅ Processed brain 840/1064 — normal
# ✅ Processed brain 841/1064 — normal
# ✅ Processed brain 842/1064 — normal
# ✅ Processed brain 843/1064 — normal
# ✅ Processed brain 844/1064 — normal
# ✅ Processed brain 845/1064 — normal
# ✅ Processed brain 846/1064 — normal
# ✅ Processed brain 847/1064 — normal
# ✅ Processed brain 848/1064 — normal
# ✅ Processed brain 849/1064 — normal
# ✅ Processed brain 850/1064 — normal
# ✅ Processed brain 851/1064 — normal
# ✅ Processed brain 852/1064 — normal
# ✅ Processed brain 853/1064 — normal
# ✅ Processed brain 854/1064 — normal
# ✅ Processed brain 855/1064 — normal
# ✅ Processed brain 856/1064 — normal
# ✅ Processed brain 857/1064 — normal
# ✅ Processed brain 858/1064 — normal
# ✅ Processed brain 859/1064 — normal
# ✅ Processed brain 860/1064 — normal
# ✅ Processed brain 861/1064 — normal
# ✅ Processed brain 862/1064 — normal
# ✅ Processed brain 863/1064 — normal
# ✅ Processed brain 864/1064 — normal
# ✅ Processed brain 865/1064 — normal
# ✅ Processed brain 866/1064 — normal
# ✅ Processed brain 867/1064 — normal
# ✅ Processed brain 868/1064 — normal
# ✅ Processed brain 869/1064 — normal
# ✅ Processed brain 870/1064 — normal
# ✅ Processed brain 871/1064 — normal
# ✅ Processed brain 872/1064 — normal
# ✅ Processed brain 873/1064 — normal
# ✅ Processed brain 874/1064 — normal
# ✅ Processed brain 875/1064 — normal
# ✅ Processed brain 876/1064 — normal
# ✅ Processed brain 877/1064 — normal
# ✅ Processed brain 878/1064 — normal
# ✅ Processed brain 879/1064 — normal
# ✅ Processed brain 880/1064 — normal
# ✅ Processed brain 881/1064 — normal
# ✅ Processed brain 882/1064 — normal
# ✅ Processed brain 883/1064 — normal
# ✅ Processed brain 884/1064 — normal
# ✅ Processed brain 885/1064 — normal
# ✅ Processed brain 886/1064 — normal
# ✅ Processed brain 887/1064 — normal
# ✅ Processed brain 888/1064 — normal
# ✅ Processed brain 889/1064 — normal
# ✅ Processed brain 890/1064 — normal
# ✅ Processed brain 891/1064 — normal
# ✅ Processed brain 892/1064 — normal
# ✅ Processed brain 893/1064 — normal
# ✅ Processed brain 894/1064 — normal
# ✅ Processed brain 895/1064 — normal
# ✅ Processed brain 896/1064 — normal
# ✅ Processed brain 897/1064 — normal
# ✅ Processed brain 898/1064 — normal
# ✅ Processed brain 899/1064 — normal
# ✅ Processed brain 900/1064 — normal
# ✅ Processed brain 901/1064 — normal
# ✅ Processed brain 902/1064 — normal
# ✅ Processed brain 903/1064 — normal
# ✅ Processed brain 904/1064 — normal
# ✅ Processed brain 905/1064 — normal
# ✅ Processed brain 906/1064 — normal
# ✅ Processed brain 907/1064 — normal
# ✅ Processed brain 908/1064 — normal
# ✅ Processed brain 909/1064 — normal
# ✅ Processed brain 910/1064 — normal
# ✅ Processed brain 911/1064 — normal
# ✅ Processed brain 912/1064 — normal
# ✅ Processed brain 913/1064 — normal
# ✅ Processed brain 914/1064 — normal
# ✅ Processed brain 915/1064 — normal
# ✅ Processed brain 916/1064 — normal
# ✅ Processed brain 917/1064 — normal
# ✅ Processed brain 918/1064 — normal
# ✅ Processed brain 919/1064 — normal
# ✅ Processed brain 920/1064 — normal
# ✅ Processed brain 921/1064 — normal
# ✅ Processed brain 922/1064 — normal
# ✅ Processed brain 923/1064 — normal
# ✅ Processed brain 924/1064 — normal
# ✅ Processed brain 925/1064 — normal
# ✅ Processed brain 926/1064 — normal
# ✅ Processed brain 927/1064 — normal
# ✅ Processed brain 928/1064 — normal
# ✅ Processed brain 929/1064 — normal
# ✅ Processed brain 930/1064 — normal
# ✅ Processed brain 931/1064 — normal
# ✅ Processed brain 932/1064 — normal
# ✅ Processed brain 933/1064 — normal
# ✅ Processed brain 934/1064 — normal
# ✅ Processed brain 935/1064 — normal
# ✅ Processed brain 936/1064 — normal
# ✅ Processed brain 937/1064 — normal
# ✅ Processed brain 938/1064 — normal
# ✅ Processed brain 939/1064 — normal
# ✅ Processed brain 940/1064 — normal
# ✅ Processed brain 941/1064 — normal
# ✅ Processed brain 942/1064 — normal
# ✅ Processed brain 943/1064 — normal
# ✅ Processed brain 944/1064 — normal
# ✅ Processed brain 945/1064 — normal
# ✅ Processed brain 946/1064 — normal
# ✅ Processed brain 947/1064 — normal
# ✅ Processed brain 948/1064 — normal
# ✅ Processed brain 949/1064 — normal
# ✅ Processed brain 950/1064 — normal
# ✅ Processed brain 951/1064 — normal
# ✅ Processed brain 952/1064 — normal
# ✅ Processed brain 953/1064 — normal
# ✅ Processed brain 954/1064 — normal
# ✅ Processed brain 955/1064 — normal
# ✅ Processed brain 956/1064 — normal
# ✅ Processed brain 957/1064 — normal
# ✅ Processed brain 958/1064 — normal
# ✅ Processed brain 959/1064 — normal
# ✅ Processed brain 960/1064 — normal
# ✅ Processed brain 961/1064 — normal
# ✅ Processed brain 962/1064 — normal
# ✅ Processed brain 963/1064 — normal
# ✅ Processed brain 964/1064 — normal
# ✅ Processed brain 965/1064 — normal
# ✅ Processed brain 966/1064 — normal
# ✅ Processed brain 967/1064 — normal
# ✅ Processed brain 968/1064 — normal
# ✅ Processed brain 969/1064 — normal
# ✅ Processed brain 970/1064 — normal
# ✅ Processed brain 971/1064 — normal
# ✅ Processed brain 972/1064 — normal
# ✅ Processed brain 973/1064 — normal
# ✅ Processed brain 974/1064 — normal
# ✅ Processed brain 975/1064 — normal
# ✅ Processed brain 976/1064 — normal
# ✅ Processed brain 977/1064 — normal
# ✅ Processed brain 978/1064 — normal
# ✅ Processed brain 979/1064 — normal
# ✅ Processed brain 980/1064 — normal
# ✅ Processed brain 981/1064 — normal
# ✅ Processed brain 982/1064 — normal
# ✅ Processed brain 983/1064 — normal
# ✅ Processed brain 984/1064 — normal
# ✅ Processed brain 985/1064 — normal
# ✅ Processed brain 986/1064 — normal
# ✅ Processed brain 987/1064 — normal
# ✅ Processed brain 988/1064 — normal
# ✅ Processed brain 989/1064 — normal
# ✅ Processed brain 990/1064 — normal
# ✅ Processed brain 991/1064 — normal
# ✅ Processed brain 992/1064 — normal
# ✅ Processed brain 993/1064 — normal
# ✅ Processed brain 994/1064 — normal
# ✅ Processed brain 995/1064 — normal
# ✅ Processed brain 996/1064 — normal
# ✅ Processed brain 997/1064 — normal
# ✅ Processed brain 998/1064 — normal
# ✅ Processed brain 999/1064 — normal
# ✅ Processed brain 1000/1064 — normal
# ✅ Processed brain 1001/1064 — normal
# ✅ Processed brain 1002/1064 — normal
# ✅ Processed brain 1003/1064 — normal
# ✅ Processed brain 1004/1064 — normal
# ✅ Processed brain 1005/1064 — normal
# ✅ Processed brain 1006/1064 — normal
# ✅ Processed brain 1007/1064 — normal
# ✅ Processed brain 1008/1064 — normal
# ✅ Processed brain 1009/1064 — normal
# ✅ Processed brain 1010/1064 — normal
# ✅ Processed brain 1011/1064 — normal
# ✅ Processed brain 1012/1064 — normal
# ✅ Processed brain 1013/1064 — normal
# ✅ Processed brain 1014/1064 — normal
# ✅ Processed brain 1015/1064 — normal
# ✅ Processed brain 1016/1064 — normal
# ✅ Processed brain 1017/1064 — normal
# ✅ Processed brain 1018/1064 — normal
# ✅ Processed brain 1019/1064 — normal
# ✅ Processed brain 1020/1064 — normal
# ✅ Processed brain 1021/1064 — normal
# ✅ Processed brain 1022/1064 — normal
# ✅ Processed brain 1023/1064 — normal
# ✅ Processed brain 1024/1064 — normal
# ✅ Processed brain 1025/1064 — normal
# ✅ Processed brain 1026/1064 — normal
# ✅ Processed brain 1027/1064 — normal
# ✅ Processed brain 1028/1064 — normal
# ✅ Processed brain 1029/1064 — normal
# ✅ Processed brain 1030/1064 — normal
# ✅ Processed brain 1031/1064 — normal
# ✅ Processed brain 1032/1064 — normal
# ✅ Processed brain 1033/1064 — normal
# ✅ Processed brain 1034/1064 — normal
# ✅ Processed brain 1035/1064 — normal
# ✅ Processed brain 1036/1064 — normal
# ✅ Processed brain 1037/1064 — normal
# ✅ Processed brain 1038/1064 — normal
# ✅ Processed brain 1039/1064 — normal
# ✅ Processed brain 1040/1064 — normal
# ✅ Processed brain 1041/1064 — normal
# ✅ Processed brain 1042/1064 — normal
# ✅ Processed brain 1043/1064 — normal
# ✅ Processed brain 1044/1064 — normal
# ✅ Processed brain 1045/1064 — normal
# ✅ Processed brain 1046/1064 — normal
# ✅ Processed brain 1047/1064 — normal
# ✅ Processed brain 1048/1064 — normal
# ✅ Processed brain 1049/1064 — normal
# ✅ Processed brain 1050/1064 — normal
# ✅ Processed brain 1051/1064 — normal
# ✅ Processed brain 1052/1064 — normal
# ✅ Processed brain 1053/1064 — normal
# ✅ Processed brain 1054/1064 — normal
# ✅ Processed brain 1055/1064 — normal
# ✅ Processed brain 1056/1064 — normal
# ✅ Processed brain 1057/1064 — normal
# ✅ Processed brain 1058/1064 — normal
# ✅ Processed brain 1059/1064 — normal
# ✅ Processed brain 1060/1064 — normal
# ✅ Processed brain 1061/1064 — normal
# ✅ Processed brain 1062/1064 — normal
# ✅ Processed brain 1063/1064 — normal
# ✅ Processed brain 1064/1064 — normal
# ✅ Dataset saved to neurocore_advice_dataset.csv
#    brain_id    mean_r    mean_V   state  \
# 0         0  0.070918 -2.249340  normal
# 1         1  0.071005 -2.246641  normal
# 2         2  0.070927 -2.249058  normal
# 3         3  0.070927 -2.249069  normal
# 4         4  0.070924 -2.249144  normal
#
#                                               advice
# 0  Dynamics within near-normal range — maintain c...
# 1  Dynamics within near-normal range — maintain c...
# 2  Dynamics within near-normal range — maintain c...
# 3  Dynamics within near-normal range — maintain c...
# 4  Dynamics within near-normal range — maintain c...
